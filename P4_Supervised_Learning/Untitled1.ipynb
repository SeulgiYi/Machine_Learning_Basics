# %%
import matplotlib
import matplotlib.font_manager

# %%
[(f.name, f.fname) for f in matplotlib.font_manager.fontManager.ttflist if 'Gothic' in f.name]
# Out:
# [('AppleGothic', '/Library/Fonts/AppleGothic.ttf'),
#  ('Hiragino Maru Gothic Pro', '/System/Library/Fonts/ヒラギノ丸ゴ ProN W4.ttc'),
#  ('Apple SD Gothic Neo', '/System/Library/Fonts/AppleSDGothicNeo.ttc')]

# %%
[(f.name, f.fname) for f in matplotlib.font_manager.fontManager.ttflist]
# Out:
# [('DejaVu Sans Display',
#   '/Users/seulgi/anaconda3/envs/ptlesson/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansDisplay.ttf'),
#  ('DejaVu Serif',
#   '/Users/seulgi/anaconda3/envs/ptlesson/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif.ttf'),
#  ('STIXSizeFiveSym',
#   '/Users/seulgi/anaconda3/envs/ptlesson/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFiveSymReg.ttf'),
#  ('STIXNonUnicode',
#   '/Users/seulgi/anaconda3/envs/ptlesson/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniIta.ttf'),
#  ('cmb10',
#   '/Users/seulgi/anaconda3/envs/ptlesson/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/cmb10.ttf'),
#  ('STIXNonUnicode',
#   '/Users/seulgi/anaconda3/envs/ptlesson/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUni.ttf'),
#  ('cmr10',
#   '/Users/seulgi/anaconda3/envs/ptlesson/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/cmr10.ttf'),
#  ('cmss10',
# ...

# %%
[(f.name) for f in matplotlib.font_manager.fontManager.ttflist]
# Out:
# ['DejaVu Sans Display',
#  'DejaVu Serif',
#  'STIXSizeFiveSym',
#  'STIXNonUnicode',
#  'cmb10',
#  'STIXNonUnicode',
#  'cmr10',
#  'cmss10',
#  'STIXGeneral',
#  'STIXSizeOneSym',
#  'STIXSizeFourSym',
#  'DejaVu Sans',
#  'DejaVu Sans Mono',
#  'STIXSizeFourSym',
#  'cmsy10',
#  'STIXGeneral',
#  'STIXSizeThreeSym',
#  'STIXNonUnicode',
#  'cmtt10',
#  'DejaVu Sans Mono',
#  'cmmi10',
#  'cmex10',
#  'DejaVu Sans Mono',
#  'STIXSizeTwoSym',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'STIXSizeOneSym',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'STIXSizeThreeSym',
#  'DejaVu Sans',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'DejaVu Sans',
#  'STIXSizeTwoSym',
#  'DejaVu Serif Display',
#  'Optima',
#  '.SF Compact Display',
#  'Rockwell',
#  'Bodoni 72 Smallcaps',
#  'Arial Black',
#  'Mshtakan',
#  'Arial Unicode MS',
#  'AppleGothic',
#  'STIXNonUnicode',
#  'DecoType Naskh',
#  'Comic Sans MS',
#  '.SF Compact Text',
# ...
